# %%
import pandas as pd

# %%
csv_file = "cities.csv"

cities_df = pd.read_csv(csv_file)
cities_df
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rikitea -23.1203 -134.9692     22.17        73         100
# 1          Pouébo -20.4000  164.5667     25.42        67          37
# 2      Port Blair  11.6667   92.7500     29.02        74          75
# 3            Kisi   9.0833    3.8500     21.27        99          77
# 4         Mataura -46.1927  168.8643     10.27        72          90
# ..            ...      ...       ...       ...       ...         ...
# 538        Mangan  27.5167   88.5333     27.80        77          90
# 539       Lebanon  36.2081  -86.2911     21.03        87           0
# 540     Champasak  14.7500  106.0000     24.49        69          81
# 541  Khorramshahr  30.4397   48.1664     29.98        94           0
# 542       Merauke  -8.4667  140.3333     29.06        73          97
#
#      Wind Speed Country        Date
# 0          3.69      PF  1663126466
# 1          0.66      NC  1663126466
# ...

# %%
cities_html = cities_df.to_html()

# %%
openfile = open("../visualisations/data.html", "w")
openfile.write(cities_html)
openfile.close()
